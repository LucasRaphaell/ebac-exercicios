# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Variáveis & Tipos de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução ao Google Colab;</li>
#   <li>Variáveis;</li>
#   <li>Números;</li>
#   <li><i>Strings;</i></li>
#   <li>Boleanos.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Google Colab

# %% [markdown]
# Crie uma célula de código que escreva o texto "Olá mundo!", utilize o comando `print`.

# %% [markdown]
# Crie uma célua de texto e adicione uma imagem.

# %%
ola_mundo = ("Olá mundo!")
print(ola_mundo)
# Out:
# Olá mundo!

# %% [markdown]
# Esta e a celula de texo com imagem!
# ![kpi-e-commerce.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Números

# %% [markdown]
# Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket médio abaixo:
#
# <br>
#
# | Dia   | Valor Total Vendas | Qtd Total Vendas | Ticket Medio |
# |-------|--------------------|------------------|--------------|
# | 19/01 | 961.56             | 3                | 320.52       |
# | 20/01 | 834.47             | 7                | 119.21       |
# | 23/01 | 15378.12           | 5                | 3075.62      |

# %%
qtde_vendas_19 = 3
ticket_medio_19 = 320.52

valor_total_vendas_dia19 = qtde_vendas_19 * ticket_medio_19
print(valor_total_vendas_dia19)
# Out:
# 961.56

# %%
valor_total_vendas_dia20 = 834.47
ticket_total_vendas_20 = 119.21

qtde_vendas_20 = valor_total_vendas_dia20 / ticket_medio_20
print(qtde_vendas_20)
# Out:
# 7.000000000000001

# %%
valor_total_vendas_dia23 = 15378.12
qtde_vendas_23 = 5

ticket_medio_23 = valor_total_vendas_dia23 / qtde_vendas_23
print(ticket_medio_23)
# Out:
# 3075.6240000000003

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Strings

# %% [markdown]
# Aplique três métodos distintos na *string* abaixo, você pode conferir alguns métodos neste [link](https://www.w3schools.com/python/python_ref_string.asp):

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

print(cancao.upper())
print(cancao.find('mundo'))
print(cancao.capitalize())
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.
# 5
# Roda mundo, roda gigante, roda moinho, roda pião.

# %% [markdown]
# Extraia da string abaixo o valor da taxa **selic** na variável `selic` e o valor do **ano** na variavel `ano`. Imprima os valores na tela.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

taxa_selic_num = noticia.find('2')
print(taxa_selic_num)

taxa_selic_porc = noticia.find('%')
print(taxa_selic_porc)

ano_selic = noticia.find('6')
print(ano_selic)

selic = noticia[12:16+1]
print(selic)
ano = noticia[62]
print(ano)
# Out:
# 12
# 16
# 62
# 2,75%
# 6

# %% [markdown]
# ---

# %% [markdown]
# ## 4\. Booleanos

# %% [markdown]
# Utilize a tabela da verdade para responder: qual o valor da variável x?

# %%
a = False
b = True

x = not a & b

print(a & b)
print(a | b)
print(x)
# Out:
# False
# True
# True
